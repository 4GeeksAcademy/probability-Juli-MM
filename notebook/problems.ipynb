# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
import random
import numpy as np


#print(dado_1)
#print(dado_2)
#print(suma_tiradas)

def n_repeticiones(n_tiradas=1000):
    contador=0
    for i in range (n_tiradas):
        dado_1=random.randint(1,6)
        dado_2=random.randint(1,6)
        suma_tiradas=dado_1+dado_2

        if suma_tiradas %2 ==0 or suma_tiradas>7:
            contador +=1
        print(i,suma_tiradas,contador)
    
    return contador / n_tiradas
n_repeticiones

print(f"The probability of rolling an even number or greater than 7 is: {np.round(n_repeticiones() * 100, 2)}%")
# Out:
# 0 6 1
# 1 12 2
# 2 9 3
# 3 4 4
# 4 7 4
# 5 8 5
# 6 7 5
# 7 6 6
# 8 6 7
# 9 7 7
# 10 6 8
# 11 12 9
# 12 7 9
# 13 6 10
# 14 8 11
# 15 7 11
# 16 6 12
# 17 3 12
# 18 11 13
# 19 9 14
# 20 11 15
# 21 12 16
# 22 4 17
# 23 7 17
# 24 3 17
# 25 9 18
# 26 5 18
# 27 4 19
# 28 7 19
# 29 7 19
# 30 7 19
# 31 6 20
# 32 3 20
# 33 3 20
# 34 10 21
# 35 6 22
# 36 9 23
# 37 5 23
# 38 4 24
# 39 9 25
# 40 4 26
# 41 10 27
# 42 4 28
# 43 8 29
# 44 6 30
# 45 8 31
# 46 5 31
# 47 12 32
# 48 9 33
# 49 7 33
# 50 10 34
# 51 11 35
# 52 8 36
# 53 4 37
# 54 7 37
# 55 6 38
# 56 8 39
# 57 5 39
# 58 9 40
# 59 8 41
# 60 12 42
# 61 6 43
# 62 8 44
# 63 8 45
# 64 7 45
# 65 10 46
# 66 6 47
# 67 5 47
# 68 3 47
# 69 10 48
# 70 6 49
# 71 6 50
# 72 10 51
# 73 6 52
# 74 7 52
# 75 7 52
# 76 8 53
# 77 7 53
# 78 6 54
# 79 6 55
# 80 6 56
# 81 9 57
# 82 4 58
# 83 9 59
# 84 9 60
# 85 8 61
# 86 11 62
# 87 4 63
# 88 6 64
# 89 8 65
# 90 8 66
# 91 9 67
# 92 9 68
# 93 8 69
# 94 6 70
# 95 11 71
# 96 6 72
# 97 8 73
# 98 7 73
# 99 5 73
# 100 5 73
# 101 5 73
# 102 6 74
# 103 8 75
# 104 10 76
# 105 7 76
# 106 11 77
# 107 6 78
# 108 5 78
# 109 8 79
# 110 11 80
# 111 7 80
# 112 10 81
# 113 7 81
# 114 7 81
# 115 5 81
# 116 3 81
# 117 12 82
# 118 10 83
# 119 10 84
# 120 4 85
# 121 7 85
# 122 3 85
# 123 8 86
# 124 8 87
# 125 7 87
# 126 8 88
# 127 2 89
# 128 2 90
# 129 9 91
# 130 9 92
# 131 3 92
# 132 9 93
# 133 9 94
# 134 5 94
# 135 7 94
# 136 4 95
# 137 6 96
# 138 6 97
# 139 6 98
# 140 12 99
# 141 4 100
# 142 8 101
# 143 7 101
# 954 8 638
# 955 10 639
# 956 4 640
# 957 4 641
# 958 8 642
# 959 6 643
# 960 6 644
# 961 8 645
# 962 9 646
# 963 7 646
# 964 8 647
# 965 3 647
# 966 5 647
# 967 7 647
# 968 6 648
# 969 6 649
# 970 8 650
# 971 10 651
# 972 10 652
# 973 5 652
# 974 5 652
# 975 7 652
# 976 2 653
# 977 8 654
# 978 3 654
# 979 9 655
# 980 6 656
# 981 7 656
# 982 8 657
# 983 11 658
# 984 9 659
# 985 9 660
# 986 10 661
# 987 4 662
# 988 9 663
# 989 6 664
# 990 3 664
# 991 9 665
# 992 2 666
# 993 9 667
# 994 7 667
# 995 5 667
# 996 7 667
# 997 10 668
# 998 9 669
# 999 7 669
# The probability of rolling an even number or greater than 7 is: 66.9%

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i >= 10) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
            
def coger_bolas(n_repeticiones = 1000):
    contador_1 = 0
    contador_2 = 0

    for i in range(n_repeticiones):
        colores = []
        for j in range(5):
            colores.append(ball_box[np.random.randint(0, 59)])
        #print(colores)
            
        # Convert list to Numpy array for better filtering
        colores = np.array(colores)
        
        bolas_blancas = sum(colores == "White")
        bolas_rojas = sum(colores == "Red")
        bolas_verdes = sum(colores == "Green")

        # Decide if we should add it to the count:
        if (bolas_blancas == 3) and (bolas_rojas == 2):
            contador_1 += 1
        
        if (bolas_blancas == 5) or (bolas_rojas == 5) or (bolas_verdes == 5):
            contador_2 += 1
    
    probability_1 = contador_1 / n_repeticiones
    probability_2 = contador_2 / n_repeticiones

    return probability_1, probability_2

coger_bolas

print(f"The probability of 3 white and 2 red is: {np.round(coger_bolas()[0] * 100, 2)}%")
print(f"The probability of all the same color is: {np.round(coger_bolas()[1] * 100, 2)}%")
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# The probability of 3 white and 2 red is: 0.8%
# The probability of all the same color is: 3.4%
